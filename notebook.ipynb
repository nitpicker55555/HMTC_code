# %%
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/praktikum/HiAGM'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Let's test the setup by simply checking if all paths are present
present = True
necessary_paths= ['exercise_code']
files = os.listdir()
for path in necessary_paths:
    if path not in files:
        present = False
if not present:
    print("Can't find all required folders. You either installed the notebook in the wrong path or didn't upload the full exercise folder. You can check your paths in the file overview on the left.")
else:
    print('Google colab setup complete! Mounted folders:')
    print(files)
# Out:
# Mounted at /content/gdrive
# Can't find all required folders. You either installed the notebook in the wrong path or didn't upload the full exercise folder. You can check your paths in the file overview on the left.

# %%
# with open("../glove.6B/glove.6B.100d.txt") as input_file:
#     head = [next(input_file) for _ in range(10)]
# print(head)

# # Read in the file
# with open('data/data_no_stopwords.json', 'r') as file :
#   filedata = file.read()

# # Replace the target string
# filedata = filedata.replace('Label', 'label')

# # Write the file out again
# with open('data/data_no_stopwords.json', 'w') as file:
#   file.write(filedata)

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
run train.py config/gcnla-rcv1-v2.json
# Out:
# INFO:  CONFIGURE: {'dataset': 'rcv1', 'data_dir': 'data', 'train_file': 'rcv1_train.json', 'val_file': 'rcv1_val.json', 'test_file': 'rcv1_test.json', 'prob_json': 'rcv1_prob.json', 'hierarchy': 'sample_rcv1.taxonomy'}
# INFO:  CONFIGURE: {'dir': 'vocab', 'vocab_dict': 'word.dict', 'max_token_vocab': 60000, 'label_dict': 'label.dict'}
# INFO:  CONFIGURE: {'dimension': 768, 'type': 'pretrain', 'pretrained_file': '../glove.6B/glove.6B.300d.txt', 'dropout': 0.5, 'init_type': 'uniform'}
# INFO:  CONFIGURE: {'dimension': 768, 'type': 'random', 'dropout': 0.5, 'init_type': 'kaiming_uniform'}
# INFO:  CONFIGURE: {'token': <helper.configure.Configure object at 0x7f6affde8cd0>, 'label': <helper.configure.Configure object at 0x7f6affde8d30>}
# INFO:  CONFIGURE: {'bidirectional': True, 'num_layers': 1, 'type': 'GRU', 'hidden_dimension': 64, 'dropout': 0.1}
# INFO:  CONFIGURE: {'kernel_size': [2, 3, 4], 'num_kernel': 256}
# INFO:  CONFIGURE: {'max_length': 256, 'RNN': <helper.configure.Configure object at 0x7f6affde8f40>, 'CNN': <helper.configure.Configure object at 0x7f6affde9060>, 'topK_max_pooling': 1}
# INFO:  CONFIGURE: {'type': 'text', 'dimension': 768, 'dropout': 0.05}
# INFO:  CONFIGURE: {'type': 'GCN', 'node': <helper.configure.Configure object at 0x7f6affde93c0>}
# INFO:  CONFIGURE: {'text_dimension': 768, 'node_dimension': 768, 'dropout': 0.5}
# INFO:  CONFIGURE: {'num_layer': 1, 'dropout': 0.5}
# INFO:  CONFIGURE: {'type': 'HiAGM-LA', 'linear_transformation': <helper.configure.Configure object at 0x7f6affde9720>, 'classifier': <helper.configure.Configure object at 0x7f6affde98d0>}
# INFO:  CONFIGURE: {'type': 'Adam', 'learning_rate': 0.0001, 'lr_decay': 1.0, 'lr_patience': 5, 'early_stopping': 200}
# INFO:  CONFIGURE: {'flag': True, 'penalty': 1e-06}
# INFO:  CONFIGURE: {'classification': 'BCEWithLogitsLoss', 'recursive_regularization': <helper.configure.Configure object at 0x7f6affde9e10>}
# INFO:  CONFIGURE: {'device': 'cuda', 'visible_device_list': '0', 'num_workers': 2}
# INFO:  CONFIGURE: {'dir': 'rcv1_hiagm_la_checkpoint', 'max_number': 0, 'save_best': ['Macro_F1', 'Micro_F1']}
# INFO:  CONFIGURE: {'optimizer': <helper.configure.Configure object at 0x7f6affde9c30>, 'batch_size': 16, 'start_epoch': 0, 'end_epoch': 1, 'loss': <helper.configure.Configure object at 0x7f6affde9de0>, 'device_setting': <helper.configure.Configure object at 0x7f6affdea140>, 'checkpoint': <helper.configure.Configure object at 0x7f6affdea2f0>}
# INFO:  CONFIGURE: {'batch_size': 96, 'threshold': 0.5}
# INFO:  CONFIGURE: {'best_checkpoint': 'best_micro_HiAGM-TP', 'batch_size': 512}
# INFO:  CONFIGURE: {'level': 'info', 'filename': 'gcnla-rcv1-v2.log'}
# INFO:  CONFIGURE: {'dict': {'data': <helper.configure.Configure object at 0x7f6affde89d0>, 'vocabulary': <helper.configure.Configure object at 0x7f6affde8c70>, 'embedding': <helper.configure.Configure object at 0x7f6affde8ca0>, 'text_encoder': <helper.configure.Configure object at 0x7f6affde8f70>, 'structure_encoder': <helper.configure.Configure object at 0x7f6affde9390>, 'model': <helper.configure.Configure object at 0x7f6affde96f0>, 'train': <helper.configure.Configure object at 0x7f6affde9c00>, 'eval': <helper.configure.Configure object at 0x7f6affdea620>, 'test': <helper.configure.Configure object at 0x7f6affdea7d0>, 'log': <helper.configure.Configure object at 0x7f6affdea980>}, 'data': <helper.configure.Configure object at 0x7f6affde89d0>, 'vocabulary': <helper.configure.Configure object at 0x7f6affde8c70>, 'embedding': <helper.configure.Configure object at 0x7f6affde8ca0>, 'text_encoder': <helper.configure.Configure object at 0x7f6affde8f70>, 'structure_encoder': <helper.configure.Configure object at 0x7f6affde9390>, 'model': <helper.configure.Configure object at 0x7f6affde96f0>, 'train': <helper.configure.Configure object at 0x7f6affde9c00>, 'eval': <helper.configure.Configure object at 0x7f6affdea620>, 'test': <helper.configure.Configure object at 0x7f6affdea7d0>, 'log': <helper.configure.Configure object at 0x7f6affdea980>}
# INFO:  Building Vocabulary....
# INFO:  Loading Vocabulary from Cached Dictionary...
# INFO:  Vocabulary of token 48595
# INFO:  Vocabulary of label 102
# Loading files for TRAIN Dataset...
# Loading files for VAL Dataset...
# Loading files for TEST Dataset...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
run evaluate.py config/gcn-rcv1-v2.json
